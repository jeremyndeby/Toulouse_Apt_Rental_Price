# %% [markdown]
# # Motivation

# %% [markdown]
# Before walking you through the project, let me tell you a little bit about the motivation behind it. Aside from Data Science and Machine Learning, my other passion is spending time in the mountains. Planning a trip to any mountain requires lots of careful planning in order to minimize the risks. That means paying close attention to the weather conditions as the summit day approaches. My absolutely favorite website for this is Mountain-Forecast.com which gives you the weather forecasts for almost any mountain in the world at different elevations. The only problem is that it doesn’t offer any historical data (as far as I can tell), which can sometimes be useful when determining if it is a good idea to make the trip or wait for better conditions.
# This problem has been in the back of my mind for a while and I finally decided to do something about it. Below, I’ll describe how I wrote a web scraper for Mountain-Forecast.com using Python and Beautiful Soup, and put it into a Raspberry Pi to collect the data on a daily basis.

# %% [markdown]
# # I. Scraping with Beautiful Soup and Selenium

# %%
import os
from bs4 import BeautifulSoup
from requests import get
import pandas as pd
import numpy as np
import itertools as it
import random
import time
from fake_useragent import UserAgent
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import sys
import regex as re

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
chromedriver = "C:/Users/jerem/Anaconda3/envs/environment-deep-learning-cookbook/Lib/site-packages/notebook/tests/selenium/chromedriver_win32/chromedriver" # path to the chromedriver executable
chromedriver = os.path.expanduser(chromedriver)
print('chromedriver path: {}'.format(chromedriver))
sys.path.append(chromedriver)

driver = webdriver.Chrome(chromedriver)
# Out:
# chromedriver path: C:/Users/jerem/Anaconda3/envs/environment-deep-learning-cookbook/Lib/site-packages/notebook/tests/selenium/chromedriver_win32/chromedriver

# %%
seloger_toulouse_url = 'https://www.seloger.com/immobilier/locations/immo-toulouse-31/bien-appartement/?LISTING-LISTpg='

def get_page_links(url, number_of_pages):
    page_links=[] # Create a list of pages links
    for i in range(1,number_of_pages+1):
        j = url + str(i)
        page_links.append(j)
    return page_links

#page_links = get_page_links(seloger_toulouse_url,3)

# %%
def get_appartment_links(pages, driver):
    
    # Setting a list of listings links
    appartment_links=[] 
    
    # Getting length of list 
    length = len(pages) 
    
    while len(pages) > 0: 
        for i in pages:
            
            #print('Extracting links from page',pages.index(i)+1,'out of',len(pages),'left')
            # we try to access a page with the new proxy
            try:
                driver.get(i)
                soup = BeautifulSoup(driver.page_source, 'html.parser')

                # Extract links information via the find_all function of the soup object 
                listings = soup.find_all("a", attrs={"name": "classified-link"})
                page_data = [row['href'] for row in listings]
                appartment_links.append(page_data) # list of listings links
                
                pages.remove(i)

                print('There are',len(pages),'pages left to examine')
                time.sleep(random.randrange(11,21))
    
            except:
                print("Skipping. Connnection error")
                time.sleep(random.randrange(300,600))
                
    return appartment_links

# %%
# Create a flatten function:
def flatten_list(appartment_links):
    appartment_links_flat=[]
    for sublist in appartment_links:
        for item in sublist:
            appartment_links_flat.append(item)
    return appartment_links_flat
        
#or appartment_links_flat = list(it.chain.from_iterable(appartment_links))

#appartment_links_flat = flatten_list(appartment_links)
# Check the number of links
#len(appartment_links_flat)

# %%
def get_title(soup):
    try:
        title = soup.title.text
        return title
    except:
        return np.nan

    
def get_agency(soup):
    try:
        agency = soup.find_all("a", class_="agence-link")
        agency2 = agency[0].text
        agency3 = agency2.replace('\n', '').lower()
        return agency3
    except:
        return np.nan
    
    
def get_housing_type(soup):
    try:
        ht = soup.find_all("h2", class_="c-h2")
        ht2 = ht[0].text
        return ht2
    except:
        return np.nan
    
    
def get_city(soup):
    try:
        city = soup.find_all("p", class_="localite")
        city2 = city[0].text
        return city2
    except:
        return np.nan
    
    
def get_details(soup):
    try:
        details = soup.find_all("h1", class_="detail-title title1")
        details2 = details[0].text
        details3 = details2.replace('\n', '').lower()
        return details3
    except:
        return np.nan
    
    
def get_rent(soup):
    try:
        rent = soup.find_all("a", class_="js-smooth-scroll-link price")
        rent2 = rent[0].text
        rent3 = int(''.join(filter(str.isdigit, rent2)))
        return rent3
    except:
        return np.nan
    
def get_charges(soup):
    try:
        cha = soup.find_all("sup", class_="u-thin u-300 u-black-snow")
        cha2 = cha[0].text
        return cha2
    except:
        return np.nan
    
    
def get_rent_info(soup):
    try:
        rent_info = soup.find_all("section", class_="categorie with-padding-bottom")
        rent_info2 = rent_info[0].find_all("p", class_="sh-text-light")
        rent_info3 = rent_info2[0].text
        return rent_info3
    except:
        return 'None'
    
    
def get_criteria(soup):
    try:
        crit = soup.find_all("section", class_="categorie")
        crit2 = [div.text for ul in crit for div in ul.find_all("div", class_="u-left")]
        crit3=(" ; ".join(crit2)) # concatenate string items in a list into a single string
        return crit3
    except:
        return 'None'
    
    
def get_energy_rating(soup):
    try:
        ener = soup.find_all("div", class_="info-detail")
        ener2 = ener[0].text
        ener3 = int(''.join(filter(str.isdigit, ener2)))
        return ener3
    except:
        return np.nan
    
    
def get_gas_rating(soup):
    try:
        gas = soup.find_all("div", class_="info-detail")
        gas2 = gas[1].text
        gas3 = int(''.join(filter(str.isdigit, gas2)))
        return gas3
    except:
        return np.nan
    
    
def get_description(soup):
    try:
        descr = soup.find_all(class_="sh-text-light")
        descr2 = descr[0].text
        return descr2
    except:
        return 'None'

# %%
def get_html_data(url, driver):
    driver.get(url)
    #time.sleep(random.lognormal(0,1))
    time.sleep(random.randrange(5,15))
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    return soup

# %%
def get_appartment_data(driver,links):
    appartment_data = []

    while len(links) > 0: 
        for i in links:

            print('Now extracting data from listing {} out of {}.'.format(links.index(i)+1,len(links)))

            # we try to access a page with the new proxy
            try:
                soup = get_html_data(i,driver)
                title = get_title(soup)
                agency = get_agency(soup)
                housing_type = get_housing_type(soup)
                city = get_city(soup)
                details = get_details(soup)
                rent = get_rent(soup)
                charges = get_charges(soup)
                rent_info = get_rent_info(soup)
                criteria = get_criteria(soup)
                energy_rating = get_energy_rating(soup)
                gas_rating = get_gas_rating(soup)
                description = get_description(soup)

                # if listings is not available anymore then remove the listing from the list
                if title == 'Location appartements Toulouse (31) | Louer appartements à Toulouse 31000': 
                    print('This appartment is no longer available.')   
                    links.remove(i)

                # if listing not accessible (robot) then go to the next one and try again later
                elif pd.isna(housing_type) == True and pd.isna(city) == True and pd.isna(rent) == True: 
                    print('You Shall Not Pass!')                    
                    time.sleep(random.randrange(300,600))

                # if access to the listing granted then extract data and remove the listing from the list
                else:
                    appartment_data.append([i,title,agency,housing_type,city,details,rent,charges,rent_info,
                                            criteria,energy_rating,gas_rating,description]) 
                    links.remove(i)
                    print('Good! There are {} listings left to examine.'.format(len(links)))

            except:
                print("Skipping. Connnection error")
                time.sleep(random.randrange(60,120))
     
    
    df = pd.DataFrame(appartment_data,columns = ['link','title','agency','housing_type','city','details','rent','charges','rent_info',
                                            'criteria','energy_rating','gas_rating','description'])
    
    return df

# %%
page_links = get_page_links(seloger_toulouse_url,96) 
appartment_links = get_appartment_links(page_links,driver)
appartment_links_flat = flatten_list(appartment_links)
df_appartment = get_appartment_data(driver,appartment_links_flat)
# Out:
# There are 95 pages left to examine
# There are 94 pages left to examine
# There are 93 pages left to examine
# There are 92 pages left to examine
# There are 91 pages left to examine
# There are 90 pages left to examine
# There are 89 pages left to examine
# There are 88 pages left to examine
# There are 87 pages left to examine
# There are 86 pages left to examine
# There are 85 pages left to examine
# There are 84 pages left to examine
# There are 83 pages left to examine
# There are 82 pages left to examine
# There are 81 pages left to examine
# There are 80 pages left to examine
# There are 79 pages left to examine
# There are 78 pages left to examine
# There are 77 pages left to examine
# There are 76 pages left to examine
# There are 75 pages left to examine
# There are 74 pages left to examine
# There are 73 pages left to examine
# There are 72 pages left to examine
# There are 71 pages left to examine
# There are 70 pages left to examine
# There are 69 pages left to examine
# There are 68 pages left to examine
# There are 67 pages left to examine
# There are 66 pages left to examine
# There are 65 pages left to examine
# There are 64 pages left to examine
# There are 63 pages left to examine
# There are 62 pages left to examine
# There are 61 pages left to examine
# There are 60 pages left to examine
# There are 59 pages left to examine
# There are 58 pages left to examine
# There are 57 pages left to examine
# There are 56 pages left to examine
# There are 55 pages left to examine
# There are 54 pages left to examine
# There are 53 pages left to examine
# There are 52 pages left to examine
# There are 51 pages left to examine
# There are 50 pages left to examine
# There are 49 pages left to examine
# There are 48 pages left to examine
# There are 47 pages left to examine
# There are 46 pages left to examine
# There are 45 pages left to examine
# There are 44 pages left to examine
# There are 43 pages left to examine
# There are 42 pages left to examine
# There are 41 pages left to examine
# There are 40 pages left to examine
# There are 39 pages left to examine
# There are 38 pages left to examine
# There are 37 pages left to examine
# There are 36 pages left to examine
# There are 35 pages left to examine
# There are 34 pages left to examine
# There are 33 pages left to examine
# There are 32 pages left to examine
# There are 31 pages left to examine
# There are 30 pages left to examine
# There are 29 pages left to examine
# There are 28 pages left to examine
# There are 27 pages left to examine
# There are 26 pages left to examine
# There are 25 pages left to examine
# There are 24 pages left to examine
# There are 23 pages left to examine
# There are 22 pages left to examine
# There are 21 pages left to examine
# There are 20 pages left to examine
# There are 19 pages left to examine
# There are 18 pages left to examine
# There are 17 pages left to examine
# There are 16 pages left to examine
# There are 15 pages left to examine
# There are 14 pages left to examine
# There are 13 pages left to examine
# There are 12 pages left to examine
# There are 11 pages left to examine
# There are 10 pages left to examine
# There are 9 pages left to examine
# There are 8 pages left to examine
# There are 7 pages left to examine
# There are 6 pages left to examine
# There are 5 pages left to examine
# There are 4 pages left to examine
# There are 3 pages left to examine
# There are 2 pages left to examine
# There are 1 pages left to examine
# There are 0 pages left to examine
# Now extracting data from listing 1 out of 2375.
# Good! There are 2374 listings left to examine.
# Now extracting data from listing 2 out of 2374.
# Good! There are 2373 listings left to examine.
# Now extracting data from listing 3 out of 2373.
# Good! There are 2372 listings left to examine.
# Now extracting data from listing 4 out of 2372.
# Good! There are 2371 listings left to examine.
# Now extracting data from listing 5 out of 2371.
# Good! There are 2370 listings left to examine.
# Now extracting data from listing 6 out of 2370.
# Good! There are 2369 listings left to examine.
# Now extracting data from listing 7 out of 2369.
# Good! There are 2368 listings left to examine.
# Now extracting data from listing 8 out of 2368.
# Good! There are 2367 listings left to examine.
# Now extracting data from listing 9 out of 2367.
# Good! There are 2366 listings left to examine.
# Now extracting data from listing 10 out of 2366.
# Good! There are 2365 listings left to examine.
# Now extracting data from listing 11 out of 2365.
# Good! There are 2364 listings left to examine.
# Now extracting data from listing 12 out of 2364.
# Good! There are 2363 listings left to examine.
# Now extracting data from listing 13 out of 2363.
# Good! There are 2362 listings left to examine.
# Now extracting data from listing 14 out of 2362.
# Good! There are 2361 listings left to examine.
# Now extracting data from listing 15 out of 2361.
# Good! There are 2360 listings left to examine.
# Now extracting data from listing 16 out of 2360.
# Good! There are 2359 listings left to examine.
# Now extracting data from listing 17 out of 2359.
# Good! There are 2358 listings left to examine.
# Now extracting data from listing 18 out of 2358.
# Good! There are 2357 listings left to examine.
# Now extracting data from listing 19 out of 2357.
# Good! There are 2356 listings left to examine.
# Now extracting data from listing 20 out of 2356.
# Good! There are 2355 listings left to examine.
# Now extracting data from listing 21 out of 2355.
# Good! There are 2354 listings left to examine.
# Now extracting data from listing 22 out of 2354.
# Good! There are 2353 listings left to examine.
# Now extracting data from listing 23 out of 2353.
# Good! There are 2352 listings left to examine.
# Now extracting data from listing 24 out of 2352.
# Good! There are 2351 listings left to examine.
# Now extracting data from listing 25 out of 2351.
# Good! There are 2350 listings left to examine.
# Now extracting data from listing 26 out of 2350.
# Good! There are 2349 listings left to examine.
# Now extracting data from listing 27 out of 2349.
# Good! There are 2348 listings left to examine.
# Now extracting data from listing 28 out of 2348.
# Good! There are 2347 listings left to examine.
# Now extracting data from listing 29 out of 2347.
# Good! There are 2346 listings left to examine.
# Now extracting data from listing 30 out of 2346.
# Good! There are 2345 listings left to examine.
# Now extracting data from listing 31 out of 2345.
# Good! There are 2344 listings left to examine.
# Now extracting data from listing 32 out of 2344.
# Good! There are 2343 listings left to examine.
# Now extracting data from listing 33 out of 2343.
# Good! There are 2342 listings left to examine.
# Now extracting data from listing 34 out of 2342.
# Good! There are 2341 listings left to examine.
# Now extracting data from listing 35 out of 2341.
# Good! There are 2340 listings left to examine.
# Now extracting data from listing 36 out of 2340.
# Good! There are 2339 listings left to examine.
# Now extracting data from listing 37 out of 2339.
# Good! There are 2338 listings left to examine.
# Now extracting data from listing 38 out of 2338.
# Good! There are 2337 listings left to examine.
# Now extracting data from listing 39 out of 2337.
# Good! There are 2336 listings left to examine.
# Now extracting data from listing 40 out of 2336.
# Good! There are 2335 listings left to examine.
# Now extracting data from listing 41 out of 2335.
# Good! There are 2334 listings left to examine.
# Now extracting data from listing 42 out of 2334.
# Good! There are 2333 listings left to examine.
# Now extracting data from listing 43 out of 2333.
# Good! There are 2332 listings left to examine.
# Now extracting data from listing 44 out of 2332.
# Good! There are 2331 listings left to examine.
# Now extracting data from listing 45 out of 2331.
# Good! There are 2330 listings left to examine.
# Now extracting data from listing 46 out of 2330.
# Good! There are 2329 listings left to examine.
# Now extracting data from listing 47 out of 2329.
# Good! There are 2328 listings left to examine.
# Now extracting data from listing 48 out of 2328.
# Good! There are 2327 listings left to examine.
# Now extracting data from listing 49 out of 2327.
# Good! There are 2326 listings left to examine.
# Now extracting data from listing 50 out of 2326.
# Good! There are 2325 listings left to examine.
# Now extracting data from listing 51 out of 2325.
# Good! There are 2324 listings left to examine.
# Now extracting data from listing 52 out of 2324.
# Good! There are 2323 listings left to examine.
# Now extracting data from listing 53 out of 2323.
# Good! There are 2322 listings left to examine.
# Now extracting data from listing 54 out of 2322.
# Good! There are 2321 listings left to examine.
# Now extracting data from listing 55 out of 2321.
# Good! There are 2320 listings left to examine.
# Now extracting data from listing 56 out of 2320.
# Good! There are 2319 listings left to examine.
# Now extracting data from listing 57 out of 2319.
# Good! There are 2318 listings left to examine.
# Now extracting data from listing 58 out of 2318.
# Good! There are 2317 listings left to examine.
# Now extracting data from listing 59 out of 2317.
# Good! There are 2316 listings left to examine.
# Now extracting data from listing 60 out of 2316.
# Good! There are 2315 listings left to examine.
# Now extracting data from listing 61 out of 2315.
# Good! There are 2314 listings left to examine.
# Now extracting data from listing 62 out of 2314.
# Good! There are 2313 listings left to examine.
# Now extracting data from listing 63 out of 2313.
# Good! There are 2312 listings left to examine.
# Now extracting data from listing 64 out of 2312.
# Good! There are 2311 listings left to examine.
# Now extracting data from listing 65 out of 2311.
# Good! There are 2310 listings left to examine.
# Now extracting data from listing 66 out of 2310.
# Good! There are 2309 listings left to examine.
# Now extracting data from listing 46 out of 2309.
# Good! There are 2308 listings left to examine.
# Now extracting data from listing 68 out of 2308.
# Good! There are 2307 listings left to examine.
# Now extracting data from listing 69 out of 2307.
# Good! There are 2306 listings left to examine.
# Now extracting data from listing 70 out of 2306.
# Good! There are 2305 listings left to examine.
# Now extracting data from listing 71 out of 2305.
# Good! There are 2304 listings left to examine.
# Now extracting data from listing 72 out of 2304.
# Good! There are 2303 listings left to examine.
# Now extracting data from listing 73 out of 2303.
# Good! There are 2302 listings left to examine.
# Now extracting data from listing 74 out of 2302.
# Good! There are 2301 listings left to examine.
# Now extracting data from listing 75 out of 2301.
# Good! There are 2300 listings left to examine.
# Now extracting data from listing 76 out of 2300.
# Good! There are 2299 listings left to examine.
# Now extracting data from listing 77 out of 2299.
# Good! There are 2298 listings left to examine.
# Now extracting data from listing 78 out of 2298.
# Good! There are 2297 listings left to examine.
# Now extracting data from listing 79 out of 2297.
# Good! There are 2296 listings left to examine.
# Now extracting data from listing 80 out of 2296.
# Good! There are 2295 listings left to examine.
# Now extracting data from listing 81 out of 2295.
# Good! There are 2294 listings left to examine.
# Now extracting data from listing 52 out of 2294.
# Good! There are 2293 listings left to examine.
# Now extracting data from listing 52 out of 2293.
# Good! There are 2292 listings left to examine.
# Now extracting data from listing 84 out of 2292.
# Good! There are 2291 listings left to examine.
# Now extracting data from listing 85 out of 2291.
# Good! There are 2290 listings left to examine.
# Now extracting data from listing 86 out of 2290.
# Good! There are 2289 listings left to examine.
# Now extracting data from listing 87 out of 2289.
# Good! There are 2288 listings left to examine.
# Now extracting data from listing 88 out of 2288.
# Good! There are 2287 listings left to examine.
# Now extracting data from listing 89 out of 2287.
# Good! There are 2286 listings left to examine.
# Now extracting data from listing 90 out of 2286.
# Good! There are 2285 listings left to examine.
# Now extracting data from listing 91 out of 2285.
# Good! There are 2284 listings left to examine.
# Now extracting data from listing 92 out of 2284.
# Good! There are 2283 listings left to examine.
# Now extracting data from listing 93 out of 2283.
# Good! There are 2282 listings left to examine.
# Now extracting data from listing 94 out of 2282.
# Good! There are 2281 listings left to examine.
# Now extracting data from listing 95 out of 2281.
# Good! There are 2280 listings left to examine.
# Now extracting data from listing 96 out of 2280.
# Good! There are 2279 listings left to examine.
# Now extracting data from listing 97 out of 2279.
# Good! There are 2278 listings left to examine.
# Now extracting data from listing 98 out of 2278.
# Good! There are 2277 listings left to examine.
# Now extracting data from listing 99 out of 2277.
# Good! There are 2276 listings left to examine.
# Now extracting data from listing 100 out of 2276.
# Good! There are 2275 listings left to examine.
# Now extracting data from listing 101 out of 2275.
# Good! There are 2274 listings left to examine.
# Now extracting data from listing 102 out of 2274.
# Good! There are 2273 listings left to examine.
# Now extracting data from listing 103 out of 2273.
# Good! There are 2272 listings left to examine.
# Now extracting data from listing 104 out of 2272.
# Good! There are 2271 listings left to examine.
# Now extracting data from listing 105 out of 2271.
# Good! There are 2270 listings left to examine.
# Now extracting data from listing 106 out of 2270.
# Good! There are 2269 listings left to examine.
# Now extracting data from listing 107 out of 2269.
# Good! There are 2268 listings left to examine.
# Now extracting data from listing 108 out of 2268.
# Good! There are 2267 listings left to examine.
# Now extracting data from listing 109 out of 2267.
# Good! There are 2266 listings left to examine.
# Now extracting data from listing 110 out of 2266.
# Good! There are 2265 listings left to examine.
# Now extracting data from listing 111 out of 2265.
# Good! There are 2264 listings left to examine.
# Now extracting data from listing 112 out of 2264.
# Good! There are 2263 listings left to examine.
# Now extracting data from listing 113 out of 2263.
# Good! There are 2262 listings left to examine.
# Now extracting data from listing 100 out of 2262.
# Good! There are 2261 listings left to examine.
# Now extracting data from listing 115 out of 2261.
# Good! There are 2260 listings left to examine.
# Now extracting data from listing 116 out of 2260.
# Good! There are 2259 listings left to examine.
# Now extracting data from listing 117 out of 2259.
# Good! There are 2258 listings left to examine.
# Now extracting data from listing 118 out of 2258.
# Good! There are 2257 listings left to examine.
# Now extracting data from listing 119 out of 2257.
# Good! There are 2256 listings left to examine.
# Now extracting data from listing 120 out of 2256.
# Good! There are 2255 listings left to examine.
# Now extracting data from listing 121 out of 2255.
# Good! There are 2254 listings left to examine.
# Now extracting data from listing 122 out of 2254.
# Good! There are 2253 listings left to examine.
# Now extracting data from listing 123 out of 2253.
# Good! There are 2252 listings left to examine.
# Now extracting data from listing 124 out of 2252.
# Good! There are 2251 listings left to examine.
# Now extracting data from listing 125 out of 2251.
# Good! There are 2250 listings left to examine.
# Now extracting data from listing 126 out of 2250.
# Good! There are 2249 listings left to examine.
# Now extracting data from listing 127 out of 2249.
# Good! There are 2248 listings left to examine.
# Now extracting data from listing 128 out of 2248.
# Good! There are 2247 listings left to examine.
# Now extracting data from listing 129 out of 2247.
# Good! There are 2246 listings left to examine.
# Now extracting data from listing 130 out of 2246.
# Good! There are 2245 listings left to examine.
# Now extracting data from listing 131 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 132 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 133 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 134 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 135 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 136 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 137 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 138 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 139 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 140 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 141 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 142 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 143 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 144 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 145 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 146 out of 2245.
# You Shall Not Pass!
# Now extracting data from listing 147 out of 2245.
# Good! There are 2244 listings left to examine.
# Now extracting data from listing 148 out of 2244.
# Good! There are 2243 listings left to examine.
# Now extracting data from listing 149 out of 2243.
# Good! There are 2242 listings left to examine.
# Now extracting data from listing 150 out of 2242.
# Good! There are 2241 listings left to examine.
# Now extracting data from listing 151 out of 2241.
# Good! There are 2240 listings left to examine.
# Now extracting data from listing 152 out of 2240.
# Good! There are 2239 listings left to examine.
# Now extracting data from listing 153 out of 2239.
# Good! There are 2238 listings left to examine.
# Now extracting data from listing 154 out of 2238.
# Good! There are 2237 listings left to examine.
# Now extracting data from listing 155 out of 2237.
# Good! There are 2236 listings left to examine.
# Now extracting data from listing 156 out of 2236.
# Good! There are 2235 listings left to examine.
# Now extracting data from listing 157 out of 2235.
# Good! There are 2234 listings left to examine.
# Now extracting data from listing 158 out of 2234.
# Good! There are 2233 listings left to examine.
# Now extracting data from listing 159 out of 2233.
# Good! There are 2232 listings left to examine.
# Now extracting data from listing 160 out of 2232.
# Good! There are 2231 listings left to examine.
# Now extracting data from listing 161 out of 2231.
# Good! There are 2230 listings left to examine.
# Now extracting data from listing 162 out of 2230.
# Good! There are 2229 listings left to examine.
# Now extracting data from listing 163 out of 2229.
# Good! There are 2228 listings left to examine.
# Now extracting data from listing 164 out of 2228.
# Good! There are 2227 listings left to examine.
# Now extracting data from listing 165 out of 2227.
# Good! There are 2226 listings left to examine.
# Now extracting data from listing 166 out of 2226.
# Good! There are 2225 listings left to examine.
# Now extracting data from listing 167 out of 2225.
# Good! There are 2224 listings left to examine.
# Now extracting data from listing 168 out of 2224.
# Good! There are 2223 listings left to examine.
# Now extracting data from listing 169 out of 2223.
# Good! There are 2222 listings left to examine.
# Now extracting data from listing 170 out of 2222.
# Good! There are 2221 listings left to examine.
# Now extracting data from listing 171 out of 2221.
# Good! There are 2220 listings left to examine.
# Now extracting data from listing 172 out of 2220.
# Good! There are 2219 listings left to examine.
# Now extracting data from listing 173 out of 2219.
# Good! There are 2218 listings left to examine.
# Now extracting data from listing 174 out of 2218.
# Good! There are 2217 listings left to examine.
# Now extracting data from listing 175 out of 2217.
# Good! There are 2216 listings left to examine.
# Now extracting data from listing 176 out of 2216.
# Good! There are 2215 listings left to examine.
# Now extracting data from listing 177 out of 2215.
# Good! There are 2214 listings left to examine.
# Now extracting data from listing 178 out of 2214.
# Good! There are 2213 listings left to examine.
# Now extracting data from listing 179 out of 2213.
# Good! There are 2212 listings left to examine.
# Now extracting data from listing 180 out of 2212.
# Good! There are 2211 listings left to examine.
# Now extracting data from listing 181 out of 2211.
# Good! There are 2210 listings left to examine.
# Now extracting data from listing 182 out of 2210.
# Good! There are 2209 listings left to examine.
# Now extracting data from listing 183 out of 2209.
# Good! There are 2208 listings left to examine.
# Now extracting data from listing 184 out of 2208.
# Good! There are 2207 listings left to examine.
# Now extracting data from listing 185 out of 2207.
# Good! There are 2206 listings left to examine.
# Now extracting data from listing 186 out of 2206.
# Good! There are 2205 listings left to examine.
# Now extracting data from listing 187 out of 2205.
# Good! There are 2204 listings left to examine.
# Now extracting data from listing 188 out of 2204.
# Good! There are 2203 listings left to examine.
# Now extracting data from listing 189 out of 2203.
# Good! There are 2202 listings left to examine.
# Now extracting data from listing 190 out of 2202.
# Good! There are 2201 listings left to examine.
# Now extracting data from listing 191 out of 2201.
# Good! There are 2200 listings left to examine.
# Now extracting data from listing 192 out of 2200.
# Good! There are 2199 listings left to examine.
# Now extracting data from listing 193 out of 2199.
# Good! There are 2198 listings left to examine.
# Now extracting data from listing 194 out of 2198.
# Good! There are 2197 listings left to examine.
# Now extracting data from listing 195 out of 2197.
# Good! There are 2196 listings left to examine.
# Now extracting data from listing 196 out of 2196.
# Good! There are 2195 listings left to examine.
# Now extracting data from listing 197 out of 2195.
# Good! There are 2194 listings left to examine.
# Now extracting data from listing 198 out of 2194.
# Good! There are 2193 listings left to examine.
# Now extracting data from listing 199 out of 2193.
# Good! There are 2192 listings left to examine.
# Now extracting data from listing 200 out of 2192.
# Good! There are 2191 listings left to examine.
# Now extracting data from listing 201 out of 2191.
# Good! There are 2190 listings left to examine.
# Now extracting data from listing 202 out of 2190.
# Good! There are 2189 listings left to examine.
# Now extracting data from listing 203 out of 2189.
# Good! There are 2188 listings left to examine.
# Now extracting data from listing 204 out of 2188.
# Good! There are 2187 listings left to examine.
# Now extracting data from listing 205 out of 2187.
# Good! There are 2186 listings left to examine.
# Now extracting data from listing 206 out of 2186.
# Good! There are 2185 listings left to examine.
# Now extracting data from listing 207 out of 2185.
# Good! There are 2184 listings left to examine.
# Now extracting data from listing 208 out of 2184.
# Good! There are 2183 listings left to examine.
# Now extracting data from listing 209 out of 2183.
# Good! There are 2182 listings left to examine.
# Now extracting data from listing 210 out of 2182.
# Good! There are 2181 listings left to examine.
# Now extracting data from listing 211 out of 2181.
# Good! There are 2180 listings left to examine.
# Now extracting data from listing 212 out of 2180.
# Good! There are 2179 listings left to examine.
# Now extracting data from listing 213 out of 2179.
# Good! There are 2178 listings left to examine.
# Now extracting data from listing 214 out of 2178.
# Good! There are 2177 listings left to examine.
# Now extracting data from listing 215 out of 2177.
# Good! There are 2176 listings left to examine.
# Now extracting data from listing 216 out of 2176.
# Good! There are 2175 listings left to examine.
# Now extracting data from listing 217 out of 2175.
# Good! There are 2174 listings left to examine.
# Now extracting data from listing 218 out of 2174.
# Good! There are 2173 listings left to examine.
# Now extracting data from listing 219 out of 2173.
# Good! There are 2172 listings left to examine.
# Now extracting data from listing 220 out of 2172.
# Good! There are 2171 listings left to examine.
# Now extracting data from listing 221 out of 2171.
# Good! There are 2170 listings left to examine.
# Now extracting data from listing 222 out of 2170.
# Good! There are 2169 listings left to examine.
# Now extracting data from listing 223 out of 2169.
# Good! There are 2168 listings left to examine.
# Now extracting data from listing 224 out of 2168.
# Good! There are 2167 listings left to examine.
# Now extracting data from listing 225 out of 2167.
# Good! There are 2166 listings left to examine.
# Now extracting data from listing 226 out of 2166.
# Good! There are 2165 listings left to examine.
# Now extracting data from listing 227 out of 2165.
# Good! There are 2164 listings left to examine.
# Now extracting data from listing 228 out of 2164.
# Good! There are 2163 listings left to examine.
# Now extracting data from listing 229 out of 2163.
# Good! There are 2162 listings left to examine.
# Now extracting data from listing 230 out of 2162.
# Good! There are 2161 listings left to examine.
# Now extracting data from listing 231 out of 2161.
# Good! There are 2160 listings left to examine.
# Now extracting data from listing 232 out of 2160.
# Good! There are 2159 listings left to examine.
# Now extracting data from listing 233 out of 2159.
# Good! There are 2158 listings left to examine.
# Now extracting data from listing 234 out of 2158.
# Good! There are 2157 listings left to examine.
# Now extracting data from listing 235 out of 2157.
# Good! There are 2156 listings left to examine.
# Now extracting data from listing 236 out of 2156.
# Good! There are 2155 listings left to examine.
# Now extracting data from listing 237 out of 2155.
# Good! There are 2154 listings left to examine.
# Now extracting data from listing 238 out of 2154.
# Good! There are 2153 listings left to examine.
# Now extracting data from listing 239 out of 2153.
# Good! There are 2152 listings left to examine.
# Now extracting data from listing 240 out of 2152.
# Good! There are 2151 listings left to examine.
# Now extracting data from listing 241 out of 2151.
# Good! There are 2150 listings left to examine.
# Now extracting data from listing 242 out of 2150.
# Good! There are 2149 listings left to examine.
# Now extracting data from listing 243 out of 2149.
# Good! There are 2148 listings left to examine.
# Now extracting data from listing 244 out of 2148.
# Good! There are 2147 listings left to examine.
# Now extracting data from listing 245 out of 2147.
# Good! There are 2146 listings left to examine.
# Now extracting data from listing 246 out of 2146.
# Good! There are 2145 listings left to examine.
# Now extracting data from listing 247 out of 2145.
# Good! There are 2144 listings left to examine.
# Now extracting data from listing 248 out of 2144.
# Good! There are 2143 listings left to examine.
# Now extracting data from listing 249 out of 2143.
# Good! There are 2142 listings left to examine.
# Now extracting data from listing 250 out of 2142.
# Good! There are 2141 listings left to examine.
# Now extracting data from listing 251 out of 2141.
# Good! There are 2140 listings left to examine.
# Now extracting data from listing 252 out of 2140.
# Good! There are 2139 listings left to examine.
# Now extracting data from listing 253 out of 2139.
# Good! There are 2138 listings left to examine.
# Now extracting data from listing 254 out of 2138.
# Good! There are 2137 listings left to examine.
# Now extracting data from listing 255 out of 2137.
# Good! There are 2136 listings left to examine.
# Now extracting data from listing 256 out of 2136.
# Good! There are 2135 listings left to examine.
# Now extracting data from listing 257 out of 2135.
# Good! There are 2134 listings left to examine.
# Now extracting data from listing 258 out of 2134.
# Good! There are 2133 listings left to examine.
# Now extracting data from listing 259 out of 2133.
# Good! There are 2132 listings left to examine.
# Now extracting data from listing 260 out of 2132.
# Good! There are 2131 listings left to examine.
# Now extracting data from listing 261 out of 2131.
# Good! There are 2130 listings left to examine.
# Now extracting data from listing 262 out of 2130.
# Good! There are 2129 listings left to examine.
# Now extracting data from listing 263 out of 2129.
# Good! There are 2128 listings left to examine.
# Now extracting data from listing 264 out of 2128.
# Good! There are 2127 listings left to examine.
# Now extracting data from listing 265 out of 2127.
# Good! There are 2126 listings left to examine.
# Now extracting data from listing 266 out of 2126.
# Good! There are 2125 listings left to examine.
# Now extracting data from listing 267 out of 2125.
# Good! There are 2124 listings left to examine.
# Now extracting data from listing 268 out of 2124.
# Good! There are 2123 listings left to examine.
# Now extracting data from listing 269 out of 2123.
# Good! There are 2122 listings left to examine.
# Now extracting data from listing 270 out of 2122.
# Good! There are 2121 listings left to examine.
# Now extracting data from listing 271 out of 2121.
# Good! There are 2120 listings left to examine.
# Now extracting data from listing 272 out of 2120.
# Good! There are 2119 listings left to examine.
# Now extracting data from listing 273 out of 2119.
# Good! There are 2118 listings left to examine.
# Now extracting data from listing 274 out of 2118.
# Good! There are 2117 listings left to examine.
# Now extracting data from listing 275 out of 2117.
# Good! There are 2116 listings left to examine.
# Now extracting data from listing 276 out of 2116.
# Good! There are 2115 listings left to examine.
# Now extracting data from listing 277 out of 2115.
# Good! There are 2114 listings left to examine.
# Now extracting data from listing 278 out of 2114.
# Good! There are 2113 listings left to examine.
# Now extracting data from listing 279 out of 2113.
# Good! There are 2112 listings left to examine.
# Now extracting data from listing 280 out of 2112.
# Good! There are 2111 listings left to examine.
# Now extracting data from listing 281 out of 2111.
# Good! There are 2110 listings left to examine.
# Now extracting data from listing 282 out of 2110.
# Good! There are 2109 listings left to examine.
# Now extracting data from listing 283 out of 2109.
# Good! There are 2108 listings left to examine.
# Now extracting data from listing 284 out of 2108.
# Good! There are 2107 listings left to examine.
# Now extracting data from listing 285 out of 2107.
# Good! There are 2106 listings left to examine.
# Now extracting data from listing 286 out of 2106.
# Good! There are 2105 listings left to examine.
# Now extracting data from listing 287 out of 2105.
# Good! There are 2104 listings left to examine.
# Now extracting data from listing 288 out of 2104.
# Good! There are 2103 listings left to examine.
# Now extracting data from listing 289 out of 2103.
# Good! There are 2102 listings left to examine.
# Now extracting data from listing 290 out of 2102.
# Good! There are 2101 listings left to examine.
# Now extracting data from listing 291 out of 2101.
# Good! There are 2100 listings left to examine.
# Now extracting data from listing 292 out of 2100.
# Good! There are 2099 listings left to examine.
# Now extracting data from listing 293 out of 2099.
# Good! There are 2098 listings left to examine.
# Now extracting data from listing 294 out of 2098.
# Good! There are 2097 listings left to examine.
# Now extracting data from listing 295 out of 2097.
# Good! There are 2096 listings left to examine.
# Now extracting data from listing 296 out of 2096.
# Good! There are 2095 listings left to examine.
# Now extracting data from listing 297 out of 2095.
# Good! There are 2094 listings left to examine.
# Now extracting data from listing 298 out of 2094.
# You Shall Not Pass!
# Now extracting data from listing 299 out of 2094.
# You Shall Not Pass!
# Now extracting data from listing 300 out of 2094.
# You Shall Not Pass!
# Now extracting data from listing 301 out of 2094.
# Good! There are 2093 listings left to examine.
# Now extracting data from listing 302 out of 2093.
# Good! There are 2092 listings left to examine.
# Now extracting data from listing 303 out of 2092.
# Good! There are 2091 listings left to examine.
# Now extracting data from listing 304 out of 2091.
# Good! There are 2090 listings left to examine.
# Now extracting data from listing 305 out of 2090.
# Good! There are 2089 listings left to examine.
# Now extracting data from listing 306 out of 2089.
# Good! There are 2088 listings left to examine.
# Now extracting data from listing 307 out of 2088.
# Good! There are 2087 listings left to examine.
# Now extracting data from listing 308 out of 2087.
# Good! There are 2086 listings left to examine.
# Now extracting data from listing 309 out of 2086.
# Good! There are 2085 listings left to examine.
# Now extracting data from listing 310 out of 2085.
# Good! There are 2084 listings left to examine.
# Now extracting data from listing 311 out of 2084.
# Good! There are 2083 listings left to examine.
# Now extracting data from listing 312 out of 2083.
# Good! There are 2082 listings left to examine.
# Now extracting data from listing 313 out of 2082.
# Good! There are 2081 listings left to examine.
# Now extracting data from listing 314 out of 2081.
# Good! There are 2080 listings left to examine.
# Now extracting data from listing 315 out of 2080.
# Good! There are 2079 listings left to examine.
# Now extracting data from listing 316 out of 2079.
# Good! There are 2078 listings left to examine.
# Now extracting data from listing 317 out of 2078.
# Good! There are 2077 listings left to examine.
# Now extracting data from listing 318 out of 2077.
# Good! There are 2076 listings left to examine.
# Now extracting data from listing 319 out of 2076.
# Good! There are 2075 listings left to examine.
# Now extracting data from listing 320 out of 2075.
# Good! There are 2074 listings left to examine.
# Now extracting data from listing 321 out of 2074.
# Good! There are 2073 listings left to examine.
# Now extracting data from listing 322 out of 2073.
# Good! There are 2072 listings left to examine.
# Now extracting data from listing 323 out of 2072.
# Good! There are 2071 listings left to examine.
# Now extracting data from listing 324 out of 2071.
# Good! There are 2070 listings left to examine.
# Now extracting data from listing 325 out of 2070.
# Good! There are 2069 listings left to examine.
# Now extracting data from listing 326 out of 2069.
# Good! There are 2068 listings left to examine.
# Now extracting data from listing 299 out of 2068.
# Good! There are 2067 listings left to examine.
# Now extracting data from listing 328 out of 2067.
# Good! There are 2066 listings left to examine.
# Now extracting data from listing 329 out of 2066.
# Good! There are 2065 listings left to examine.
# Now extracting data from listing 330 out of 2065.
# Good! There are 2064 listings left to examine.
# Now extracting data from listing 304 out of 2064.
# Good! There are 2063 listings left to examine.
# Now extracting data from listing 305 out of 2063.
# Good! There are 2062 listings left to examine.
# Now extracting data from listing 333 out of 2062.
# Good! There are 2061 listings left to examine.
# Now extracting data from listing 306 out of 2061.
# Good! There are 2060 listings left to examine.
# Now extracting data from listing 335 out of 2060.
# Good! There are 2059 listings left to examine.
# Now extracting data from listing 336 out of 2059.
# Good! There are 2058 listings left to examine.
# Now extracting data from listing 337 out of 2058.
# Good! There are 2057 listings left to examine.
# Now extracting data from listing 338 out of 2057.
# Good! There are 2056 listings left to examine.
# Now extracting data from listing 339 out of 2056.
# Good! There are 2055 listings left to examine.
# Now extracting data from listing 340 out of 2055.
# Good! There are 2054 listings left to examine.
# Now extracting data from listing 341 out of 2054.
# Good! There are 2053 listings left to examine.
# Now extracting data from listing 342 out of 2053.
# Good! There are 2052 listings left to examine.
# Now extracting data from listing 343 out of 2052.
# Good! There are 2051 listings left to examine.
# Now extracting data from listing 344 out of 2051.
# Good! There are 2050 listings left to examine.
# Now extracting data from listing 345 out of 2050.
# Good! There are 2049 listings left to examine.
# Now extracting data from listing 346 out of 2049.
# Good! There are 2048 listings left to examine.
# Now extracting data from listing 347 out of 2048.
# Good! There are 2047 listings left to examine.
# Now extracting data from listing 348 out of 2047.
# Good! There are 2046 listings left to examine.
# Now extracting data from listing 349 out of 2046.
# Good! There are 2045 listings left to examine.
# Now extracting data from listing 350 out of 2045.
# Good! There are 2044 listings left to examine.
# Now extracting data from listing 351 out of 2044.
# Good! There are 2043 listings left to examine.
# Now extracting data from listing 352 out of 2043.
# Good! There are 2042 listings left to examine.
# Now extracting data from listing 353 out of 2042.
# Good! There are 2041 listings left to examine.
# Now extracting data from listing 354 out of 2041.
# Good! There are 2040 listings left to examine.
# Now extracting data from listing 355 out of 2040.
# Good! There are 2039 listings left to examine.
# Now extracting data from listing 356 out of 2039.
# Good! There are 2038 listings left to examine.
# Now extracting data from listing 357 out of 2038.
# Good! There are 2037 listings left to examine.
# Now extracting data from listing 358 out of 2037.
# Good! There are 2036 listings left to examine.
# Now extracting data from listing 359 out of 2036.
# Good! There are 2035 listings left to examine.
# Now extracting data from listing 360 out of 2035.
# Good! There are 2034 listings left to examine.
# Now extracting data from listing 361 out of 2034.
# Good! There are 2033 listings left to examine.
# Now extracting data from listing 362 out of 2033.
# Good! There are 2032 listings left to examine.
# Now extracting data from listing 363 out of 2032.
# Good! There are 2031 listings left to examine.
# Now extracting data from listing 364 out of 2031.
# Good! There are 2030 listings left to examine.
# Now extracting data from listing 365 out of 2030.
# Good! There are 2029 listings left to examine.
# Now extracting data from listing 366 out of 2029.
# Good! There are 2028 listings left to examine.
# Now extracting data from listing 367 out of 2028.
# Good! There are 2027 listings left to examine.
# Now extracting data from listing 368 out of 2027.
# Good! There are 2026 listings left to examine.
# Now extracting data from listing 369 out of 2026.
# Good! There are 2025 listings left to examine.
# Now extracting data from listing 370 out of 2025.
# Good! There are 2024 listings left to examine.
# Now extracting data from listing 371 out of 2024.
# Good! There are 2023 listings left to examine.
# Now extracting data from listing 372 out of 2023.
# Good! There are 2022 listings left to examine.
# Now extracting data from listing 373 out of 2022.
# Good! There are 2021 listings left to examine.
# Now extracting data from listing 374 out of 2021.
# Good! There are 2020 listings left to examine.
# Now extracting data from listing 375 out of 2020.
# Good! There are 2019 listings left to examine.
# Now extracting data from listing 376 out of 2019.
# Good! There are 2018 listings left to examine.
# Now extracting data from listing 377 out of 2018.
# Good! There are 2017 listings left to examine.
# Now extracting data from listing 378 out of 2017.
# Good! There are 2016 listings left to examine.
# Now extracting data from listing 379 out of 2016.
# Good! There are 2015 listings left to examine.
# Now extracting data from listing 380 out of 2015.
# Good! There are 2014 listings left to examine.
# Now extracting data from listing 381 out of 2014.
# Good! There are 2013 listings left to examine.
# Now extracting data from listing 382 out of 2013.
# Good! There are 2012 listings left to examine.
# Now extracting data from listing 383 out of 2012.
# Good! There are 2011 listings left to examine.
# Now extracting data from listing 384 out of 2011.
# Good! There are 2010 listings left to examine.
# Now extracting data from listing 385 out of 2010.
# Good! There are 2009 listings left to examine.
# Now extracting data from listing 386 out of 2009.
# Good! There are 2008 listings left to examine.
# Now extracting data from listing 387 out of 2008.
# Good! There are 2007 listings left to examine.
# Now extracting data from listing 388 out of 2007.
# Good! There are 2006 listings left to examine.
# Now extracting data from listing 389 out of 2006.
# Good! There are 2005 listings left to examine.
# Now extracting data from listing 390 out of 2005.
# Good! There are 2004 listings left to examine.
# Now extracting data from listing 391 out of 2004.
# Good! There are 2003 listings left to examine.
# Now extracting data from listing 392 out of 2003.
# Good! There are 2002 listings left to examine.
# Now extracting data from listing 393 out of 2002.
# Good! There are 2001 listings left to examine.
# Now extracting data from listing 394 out of 2001.
# Good! There are 2000 listings left to examine.
# Now extracting data from listing 395 out of 2000.
# Good! There are 1999 listings left to examine.
# Now extracting data from listing 396 out of 1999.
# Good! There are 1998 listings left to examine.
# Now extracting data from listing 397 out of 1998.
# Good! There are 1997 listings left to examine.
# Now extracting data from listing 398 out of 1997.
# Good! There are 1996 listings left to examine.
# Now extracting data from listing 399 out of 1996.
# Good! There are 1995 listings left to examine.
# Now extracting data from listing 400 out of 1995.
# Good! There are 1994 listings left to examine.
# Now extracting data from listing 401 out of 1994.
# Good! There are 1993 listings left to examine.
# Now extracting data from listing 402 out of 1993.
# Good! There are 1992 listings left to examine.
# Now extracting data from listing 403 out of 1992.
# Good! There are 1991 listings left to examine.
# Now extracting data from listing 404 out of 1991.
# Good! There are 1990 listings left to examine.
# Now extracting data from listing 405 out of 1990.
# Good! There are 1989 listings left to examine.
# Now extracting data from listing 406 out of 1989.
# Good! There are 1988 listings left to examine.
# Now extracting data from listing 407 out of 1988.
# Good! There are 1987 listings left to examine.
# Now extracting data from listing 408 out of 1987.
# Good! There are 1986 listings left to examine.
# Now extracting data from listing 409 out of 1986.
# Good! There are 1985 listings left to examine.
# Now extracting data from listing 410 out of 1985.
# Good! There are 1984 listings left to examine.
# Now extracting data from listing 411 out of 1984.
# Good! There are 1983 listings left to examine.
# Now extracting data from listing 412 out of 1983.
# Good! There are 1982 listings left to examine.
# Now extracting data from listing 413 out of 1982.
# Good! There are 1981 listings left to examine.
# Now extracting data from listing 414 out of 1981.
# Good! There are 1980 listings left to examine.
# Now extracting data from listing 415 out of 1980.
# Good! There are 1979 listings left to examine.
# Now extracting data from listing 416 out of 1979.
# Good! There are 1978 listings left to examine.
# Now extracting data from listing 417 out of 1978.
# Good! There are 1977 listings left to examine.
# Now extracting data from listing 418 out of 1977.
# Good! There are 1976 listings left to examine.
# Now extracting data from listing 419 out of 1976.
# Good! There are 1975 listings left to examine.
# Now extracting data from listing 420 out of 1975.
# Good! There are 1974 listings left to examine.
# Now extracting data from listing 421 out of 1974.
# Good! There are 1973 listings left to examine.
# Now extracting data from listing 422 out of 1973.
# Good! There are 1972 listings left to examine.
# Now extracting data from listing 423 out of 1972.
# Good! There are 1971 listings left to examine.
# Now extracting data from listing 424 out of 1971.
# Good! There are 1970 listings left to examine.
# Now extracting data from listing 425 out of 1970.
# Good! There are 1969 listings left to examine.
# Now extracting data from listing 426 out of 1969.
# Good! There are 1968 listings left to examine.
# Now extracting data from listing 427 out of 1968.
# Good! There are 1967 listings left to examine.
# Now extracting data from listing 428 out of 1967.
# Good! There are 1966 listings left to examine.
# Now extracting data from listing 429 out of 1966.
# Good! There are 1965 listings left to examine.
# Now extracting data from listing 430 out of 1965.
# Good! There are 1964 listings left to examine.
# Now extracting data from listing 431 out of 1964.
# Good! There are 1963 listings left to examine.
# Now extracting data from listing 432 out of 1963.
# Good! There are 1962 listings left to examine.
# Now extracting data from listing 433 out of 1962.
# Good! There are 1961 listings left to examine.
# Now extracting data from listing 434 out of 1961.
# Good! There are 1960 listings left to examine.
# Now extracting data from listing 435 out of 1960.
# Good! There are 1959 listings left to examine.
# Now extracting data from listing 436 out of 1959.
# Good! There are 1958 listings left to examine.
# Now extracting data from listing 437 out of 1958.
# Good! There are 1957 listings left to examine.
# Now extracting data from listing 438 out of 1957.
# Good! There are 1956 listings left to examine.
# Now extracting data from listing 439 out of 1956.
# Good! There are 1955 listings left to examine.
# Now extracting data from listing 440 out of 1955.
# Good! There are 1954 listings left to examine.
# Now extracting data from listing 441 out of 1954.
# Good! There are 1953 listings left to examine.
# Now extracting data from listing 442 out of 1953.
# Good! There are 1952 listings left to examine.
# Now extracting data from listing 443 out of 1952.
# Good! There are 1951 listings left to examine.
# Now extracting data from listing 444 out of 1951.
# Good! There are 1950 listings left to examine.
# Now extracting data from listing 445 out of 1950.
# Good! There are 1949 listings left to examine.
# Now extracting data from listing 446 out of 1949.
# Good! There are 1948 listings left to examine.
# Now extracting data from listing 447 out of 1948.
# Good! There are 1947 listings left to examine.
# Now extracting data from listing 448 out of 1947.
# Good! There are 1946 listings left to examine.
# Now extracting data from listing 449 out of 1946.
# Good! There are 1945 listings left to examine.
# Now extracting data from listing 450 out of 1945.
# Good! There are 1944 listings left to examine.
# Now extracting data from listing 451 out of 1944.
# Good! There are 1943 listings left to examine.
# Now extracting data from listing 452 out of 1943.
# Good! There are 1942 listings left to examine.
# Now extracting data from listing 453 out of 1942.
# Good! There are 1941 listings left to examine.
# Now extracting data from listing 454 out of 1941.
# Good! There are 1940 listings left to examine.
# Now extracting data from listing 455 out of 1940.
# Good! There are 1939 listings left to examine.
# Now extracting data from listing 456 out of 1939.
# Good! There are 1938 listings left to examine.
# Now extracting data from listing 457 out of 1938.
# Good! There are 1937 listings left to examine.
# Now extracting data from listing 458 out of 1937.
# Good! There are 1936 listings left to examine.
# Now extracting data from listing 459 out of 1936.
# Good! There are 1935 listings left to examine.
# Now extracting data from listing 460 out of 1935.
# Good! There are 1934 listings left to examine.
# Now extracting data from listing 461 out of 1934.
# Good! There are 1933 listings left to examine.
# Now extracting data from listing 462 out of 1933.
# Good! There are 1932 listings left to examine.
# Now extracting data from listing 463 out of 1932.
# Good! There are 1931 listings left to examine.
# Now extracting data from listing 464 out of 1931.
# Good! There are 1930 listings left to examine.
# Now extracting data from listing 465 out of 1930.
# Good! There are 1929 listings left to examine.
# Now extracting data from listing 466 out of 1929.
# Good! There are 1928 listings left to examine.
# Now extracting data from listing 467 out of 1928.
# ...
# Good! There are 172 listings left to examine.
# Now extracting data from listing 23 out of 172.
# Good! There are 171 listings left to examine.
# Now extracting data from listing 24 out of 171.
# Good! There are 170 listings left to examine.
# Now extracting data from listing 25 out of 170.
# Good! There are 169 listings left to examine.
# Now extracting data from listing 26 out of 169.
# Good! There are 168 listings left to examine.
# Now extracting data from listing 27 out of 168.
# Good! There are 167 listings left to examine.
# Now extracting data from listing 28 out of 167.
# Good! There are 166 listings left to examine.
# Now extracting data from listing 29 out of 166.
# Good! There are 165 listings left to examine.
# Now extracting data from listing 30 out of 165.
# Good! There are 164 listings left to examine.
# Now extracting data from listing 31 out of 164.
# Good! There are 163 listings left to examine.
# Now extracting data from listing 32 out of 163.
# Good! There are 162 listings left to examine.
# Now extracting data from listing 33 out of 162.
# Good! There are 161 listings left to examine.
# Now extracting data from listing 34 out of 161.
# Good! There are 160 listings left to examine.
# Now extracting data from listing 35 out of 160.
# Good! There are 159 listings left to examine.
# Now extracting data from listing 36 out of 159.
# Good! There are 158 listings left to examine.
# Now extracting data from listing 37 out of 158.
# Good! There are 157 listings left to examine.
# Now extracting data from listing 38 out of 157.
# Good! There are 156 listings left to examine.
# Now extracting data from listing 39 out of 156.
# Good! There are 155 listings left to examine.
# Now extracting data from listing 40 out of 155.
# Good! There are 154 listings left to examine.
# Now extracting data from listing 41 out of 154.
# Good! There are 153 listings left to examine.
# Now extracting data from listing 42 out of 153.
# Good! There are 152 listings left to examine.
# Now extracting data from listing 43 out of 152.
# Good! There are 151 listings left to examine.
# Now extracting data from listing 44 out of 151.
# Good! There are 150 listings left to examine.
# Now extracting data from listing 45 out of 150.
# Good! There are 149 listings left to examine.
# Now extracting data from listing 46 out of 149.
# Good! There are 148 listings left to examine.
# Now extracting data from listing 47 out of 148.
# Good! There are 147 listings left to examine.
# Now extracting data from listing 48 out of 147.
# Good! There are 146 listings left to examine.
# Now extracting data from listing 49 out of 146.
# Good! There are 145 listings left to examine.
# Now extracting data from listing 50 out of 145.
# Good! There are 144 listings left to examine.
# Now extracting data from listing 25 out of 144.
# Good! There are 143 listings left to examine.
# Now extracting data from listing 52 out of 143.
# Good! There are 142 listings left to examine.
# Now extracting data from listing 53 out of 142.
# Good! There are 141 listings left to examine.
# Now extracting data from listing 54 out of 141.
# Good! There are 140 listings left to examine.
# Now extracting data from listing 55 out of 140.
# Good! There are 139 listings left to examine.
# Now extracting data from listing 56 out of 139.
# Good! There are 138 listings left to examine.
# Now extracting data from listing 57 out of 138.
# Good! There are 137 listings left to examine.
# Now extracting data from listing 58 out of 137.
# You Shall Not Pass!
# Now extracting data from listing 59 out of 137.
# Good! There are 136 listings left to examine.
# Now extracting data from listing 60 out of 136.
# Good! There are 135 listings left to examine.
# Now extracting data from listing 61 out of 135.
# Good! There are 134 listings left to examine.
# Now extracting data from listing 62 out of 134.
# Good! There are 133 listings left to examine.
# Now extracting data from listing 63 out of 133.
# Good! There are 132 listings left to examine.
# Now extracting data from listing 64 out of 132.
# This appartment is no longer available.
# Now extracting data from listing 65 out of 131.
# Good! There are 130 listings left to examine.
# Now extracting data from listing 66 out of 130.
# Good! There are 129 listings left to examine.
# Now extracting data from listing 67 out of 129.
# Good! There are 128 listings left to examine.
# Now extracting data from listing 68 out of 128.
# Good! There are 127 listings left to examine.
# Now extracting data from listing 69 out of 127.
# Good! There are 126 listings left to examine.
# Now extracting data from listing 70 out of 126.
# Good! There are 125 listings left to examine.
# Now extracting data from listing 71 out of 125.
# Good! There are 124 listings left to examine.
# Now extracting data from listing 72 out of 124.
# Good! There are 123 listings left to examine.
# Now extracting data from listing 73 out of 123.
# Good! There are 122 listings left to examine.
# Now extracting data from listing 74 out of 122.
# Good! There are 121 listings left to examine.
# Now extracting data from listing 75 out of 121.
# Good! There are 120 listings left to examine.
# Now extracting data from listing 76 out of 120.
# Good! There are 119 listings left to examine.
# Now extracting data from listing 77 out of 119.
# Good! There are 118 listings left to examine.
# Now extracting data from listing 78 out of 118.
# Good! There are 117 listings left to examine.
# Now extracting data from listing 79 out of 117.
# Good! There are 116 listings left to examine.
# Now extracting data from listing 80 out of 116.
# Good! There are 115 listings left to examine.
# Now extracting data from listing 81 out of 115.
# Good! There are 114 listings left to examine.
# Now extracting data from listing 82 out of 114.
# Good! There are 113 listings left to examine.
# Now extracting data from listing 83 out of 113.
# Good! There are 112 listings left to examine.
# Now extracting data from listing 84 out of 112.
# Good! There are 111 listings left to examine.
# Now extracting data from listing 85 out of 111.
# Good! There are 110 listings left to examine.
# Now extracting data from listing 86 out of 110.
# Good! There are 109 listings left to examine.
# Now extracting data from listing 87 out of 109.
# Good! There are 108 listings left to examine.
# Now extracting data from listing 88 out of 108.
# Good! There are 107 listings left to examine.
# Now extracting data from listing 89 out of 107.
# Good! There are 106 listings left to examine.
# Now extracting data from listing 34 out of 106.
# Good! There are 105 listings left to examine.
# Now extracting data from listing 91 out of 105.
# Good! There are 104 listings left to examine.
# Now extracting data from listing 92 out of 104.
# Good! There are 103 listings left to examine.
# Now extracting data from listing 93 out of 103.
# Good! There are 102 listings left to examine.
# Now extracting data from listing 94 out of 102.
# Good! There are 101 listings left to examine.
# Now extracting data from listing 95 out of 101.
# Good! There are 100 listings left to examine.
# Now extracting data from listing 96 out of 100.
# Good! There are 99 listings left to examine.
# Now extracting data from listing 97 out of 99.
# This appartment is no longer available.
# Now extracting data from listing 98 out of 98.
# Good! There are 97 listings left to examine.
# Now extracting data from listing 1 out of 97.
# Good! There are 96 listings left to examine.
# Now extracting data from listing 2 out of 96.
# Good! There are 95 listings left to examine.
# Now extracting data from listing 3 out of 95.
# Good! There are 94 listings left to examine.
# Now extracting data from listing 4 out of 94.
# Good! There are 93 listings left to examine.
# Now extracting data from listing 5 out of 93.
# Good! There are 92 listings left to examine.
# Now extracting data from listing 6 out of 92.
# Good! There are 91 listings left to examine.
# Now extracting data from listing 7 out of 91.
# Good! There are 90 listings left to examine.
# Now extracting data from listing 8 out of 90.
# Good! There are 89 listings left to examine.
# Now extracting data from listing 9 out of 89.
# Good! There are 88 listings left to examine.
# Now extracting data from listing 10 out of 88.
# Good! There are 87 listings left to examine.
# Now extracting data from listing 11 out of 87.
# Good! There are 86 listings left to examine.
# Now extracting data from listing 12 out of 86.
# Good! There are 85 listings left to examine.
# Now extracting data from listing 13 out of 85.
# Good! There are 84 listings left to examine.
# Now extracting data from listing 14 out of 84.
# Good! There are 83 listings left to examine.
# Now extracting data from listing 15 out of 83.
# Good! There are 82 listings left to examine.
# Now extracting data from listing 16 out of 82.
# Good! There are 81 listings left to examine.
# Now extracting data from listing 17 out of 81.
# Good! There are 80 listings left to examine.
# Now extracting data from listing 18 out of 80.
# Good! There are 79 listings left to examine.
# Now extracting data from listing 19 out of 79.
# Good! There are 78 listings left to examine.
# Now extracting data from listing 20 out of 78.
# Good! There are 77 listings left to examine.
# Now extracting data from listing 21 out of 77.
# Good! There are 76 listings left to examine.
# Now extracting data from listing 22 out of 76.
# Good! There are 75 listings left to examine.
# Now extracting data from listing 23 out of 75.
# Good! There are 74 listings left to examine.
# Now extracting data from listing 24 out of 74.
# Good! There are 73 listings left to examine.
# Now extracting data from listing 25 out of 73.
# Good! There are 72 listings left to examine.
# Now extracting data from listing 26 out of 72.
# Good! There are 71 listings left to examine.
# Now extracting data from listing 27 out of 71.
# Good! There are 70 listings left to examine.
# Now extracting data from listing 28 out of 70.
# Good! There are 69 listings left to examine.
# Now extracting data from listing 29 out of 69.
# Good! There are 68 listings left to examine.
# Now extracting data from listing 30 out of 68.
# Good! There are 67 listings left to examine.
# Now extracting data from listing 31 out of 67.
# Good! There are 66 listings left to examine.
# Now extracting data from listing 32 out of 66.
# Good! There are 65 listings left to examine.
# Now extracting data from listing 33 out of 65.
# Good! There are 64 listings left to examine.
# Now extracting data from listing 34 out of 64.
# Good! There are 63 listings left to examine.
# Now extracting data from listing 35 out of 63.
# Good! There are 62 listings left to examine.
# Now extracting data from listing 36 out of 62.
# Good! There are 61 listings left to examine.
# Now extracting data from listing 37 out of 61.
# Good! There are 60 listings left to examine.
# Now extracting data from listing 38 out of 60.
# Good! There are 59 listings left to examine.
# Now extracting data from listing 25 out of 59.
# Good! There are 58 listings left to examine.
# Now extracting data from listing 40 out of 58.
# Good! There are 57 listings left to examine.
# Now extracting data from listing 41 out of 57.
# Good! There are 56 listings left to examine.
# Now extracting data from listing 42 out of 56.
# Good! There are 55 listings left to examine.
# Now extracting data from listing 43 out of 55.
# Good! There are 54 listings left to examine.
# Now extracting data from listing 44 out of 54.
# Good! There are 53 listings left to examine.
# Now extracting data from listing 45 out of 53.
# Good! There are 52 listings left to examine.
# Now extracting data from listing 46 out of 52.
# Good! There are 51 listings left to examine.
# Now extracting data from listing 47 out of 51.
# Good! There are 50 listings left to examine.
# Now extracting data from listing 48 out of 50.
# Good! There are 49 listings left to examine.
# Now extracting data from listing 49 out of 49.
# Good! There are 48 listings left to examine.
# Now extracting data from listing 1 out of 48.
# Good! There are 47 listings left to examine.
# Now extracting data from listing 2 out of 47.
# Good! There are 46 listings left to examine.
# Now extracting data from listing 3 out of 46.
# Good! There are 45 listings left to examine.
# Now extracting data from listing 4 out of 45.
# Good! There are 44 listings left to examine.
# Now extracting data from listing 5 out of 44.
# Good! There are 43 listings left to examine.
# Now extracting data from listing 6 out of 43.
# Good! There are 42 listings left to examine.
# Now extracting data from listing 7 out of 42.
# Good! There are 41 listings left to examine.
# Now extracting data from listing 8 out of 41.
# Good! There are 40 listings left to examine.
# Now extracting data from listing 9 out of 40.
# Good! There are 39 listings left to examine.
# Now extracting data from listing 10 out of 39.
# Good! There are 38 listings left to examine.
# Now extracting data from listing 11 out of 38.
# Good! There are 37 listings left to examine.
# Now extracting data from listing 12 out of 37.
# This appartment is no longer available.
# Now extracting data from listing 13 out of 36.
# Good! There are 35 listings left to examine.
# Now extracting data from listing 14 out of 35.
# Good! There are 34 listings left to examine.
# Now extracting data from listing 15 out of 34.
# Good! There are 33 listings left to examine.
# Now extracting data from listing 16 out of 33.
# Good! There are 32 listings left to examine.
# Now extracting data from listing 17 out of 32.
# Good! There are 31 listings left to examine.
# Now extracting data from listing 18 out of 31.
# Good! There are 30 listings left to examine.
# Now extracting data from listing 19 out of 30.
# Good! There are 29 listings left to examine.
# Now extracting data from listing 20 out of 29.
# Good! There are 28 listings left to examine.
# Now extracting data from listing 21 out of 28.
# Good! There are 27 listings left to examine.
# Now extracting data from listing 22 out of 27.
# Good! There are 26 listings left to examine.
# Now extracting data from listing 23 out of 26.
# This appartment is no longer available.
# Now extracting data from listing 24 out of 25.
# Good! There are 24 listings left to examine.
# Now extracting data from listing 1 out of 24.
# Good! There are 23 listings left to examine.
# Now extracting data from listing 2 out of 23.
# Good! There are 22 listings left to examine.
# Now extracting data from listing 3 out of 22.
# Good! There are 21 listings left to examine.
# Now extracting data from listing 4 out of 21.
# Good! There are 20 listings left to examine.
# Now extracting data from listing 5 out of 20.
# Good! There are 19 listings left to examine.
# Now extracting data from listing 6 out of 19.
# Good! There are 18 listings left to examine.
# Now extracting data from listing 7 out of 18.
# Good! There are 17 listings left to examine.
# Now extracting data from listing 8 out of 17.
# This appartment is no longer available.
# Now extracting data from listing 9 out of 16.
# Good! There are 15 listings left to examine.
# Now extracting data from listing 10 out of 15.
# Good! There are 14 listings left to examine.
# Now extracting data from listing 11 out of 14.
# Good! There are 13 listings left to examine.
# Now extracting data from listing 12 out of 13.
# Good! There are 12 listings left to examine.
# Now extracting data from listing 1 out of 12.
# Good! There are 11 listings left to examine.
# Now extracting data from listing 2 out of 11.
# Good! There are 10 listings left to examine.
# Now extracting data from listing 3 out of 10.
# Good! There are 9 listings left to examine.
# Now extracting data from listing 4 out of 9.
# Good! There are 8 listings left to examine.
# Now extracting data from listing 5 out of 8.
# Good! There are 7 listings left to examine.
# Now extracting data from listing 6 out of 7.
# Good! There are 6 listings left to examine.
# Now extracting data from listing 1 out of 6.
# Good! There are 5 listings left to examine.
# Now extracting data from listing 2 out of 5.
# Good! There are 4 listings left to examine.
# Now extracting data from listing 3 out of 4.
# Good! There are 3 listings left to examine.
# Now extracting data from listing 1 out of 3.
# Good! There are 2 listings left to examine.
# Now extracting data from listing 2 out of 2.
# Good! There are 1 listings left to examine.
# Now extracting data from listing 1 out of 1.
# Good! There are 0 listings left to examine.

# %%
df_appartment.shape
# Out:
# (2338, 13)

# %%
df_appartment.head()
# Out:
#                                                 link  \
# 0  https://www.seloger.com/annonces/locations/app...
# 1  https://www.seloger.com/annonces/locations/app...
# 2  https://www.seloger.com/annonces/locations/app...
# 3  https://www.seloger.com/annonces/locations/app...
# 4  https://www.seloger.com/annonces/locations/app...
#
#                                                title               agency  \
# 0  Location appartement 2 pièces Toulouse - appar...       zaf immobilier
# 1  Location appartement 3 pièces Toulouse - appar...                eurim
# 2  Location appartement 4 pièces Toulouse - appar...                eurim
# 3  Location appartement 2 pièces Toulouse - appar...  sporting immobilier
# 4  Location appartement 3 pièces Toulouse - appar...          cdc habitat
#
#   housing_type      city                                            details  \
# 0  Appartement  Toulouse                  location appartement 42,03m² t...
# 1  Appartement  Toulouse                  location appartement 85m² toul...
# 2  Appartement  Toulouse                  location appartement 90,7m² to...
# 3  Appartement  Toulouse                  location appartement 42m² toul...
# 4  Appartement  Toulouse                  location appartement 66m² toul...
#
#    rent charges                                          rent_info  \
# 0   590      CC                                               None
# 1  1650      CC  \n                        Loyer : 1,650 € / mo...
# 2  1351      CC  \n                        Loyer : 1,351 € / mo...
# 3   545      CC                                               None
# 4   685      CC                                               None
#
#                                             criteria  energy_rating  \
# 0  Surface de 42,03 m² ; Au 3ème étage ; 2 Pièces...          227.0
# 1  Ascenseur ; Orientation Ouest ; Vue ; Refait À...            NaN
# 2  Ascenseur ; Orientation Est, Sud ; Vue ; Surfa...          148.0
# 3  Ascenseur ; 1 Balcon ; Surface de 42 m² ; Bâti...           61.0
# 4  Ascenseur ; 1 Balcon ; Orientation Ouest ; Sur...           66.0
#
#    gas_rating                                        description
# 0        10.0  Votre agence ZAF IMMOBILIER vous propose: Char...
# 1         NaN  Wilson - Vue exceptionnelle WILSON - Superbe v...
# 2         7.0  COMPANS - PLACE DE L'EUROPE Compans-Caffarelli...
# 3        14.0  APT 109\nSPORTING IMMOBILIER VOUS OFFRE L INTÉ...
# 4        15.0  SANS HONORAIRES. Dans immeuble sécurisée de 20...

# %%
df_appartment.to_csv('data_seloger_scraping_part1.csv',index=False)

# %% [markdown]
# Next steps for improvement:
# - Rotate the user agent
# - Rotate of proxies (proxy pool)
# - Only extract the new listings to consolidate our data: Trier par date => afin d’avoir les offres récentes (le but étant de ne pas scraper 2 fois la même annonce, donc si 200 nouvelles annonces ont été publiées depuis hier, le scrap d’aujourd’hui doit s’arrêter quand il aura scraper ces 200 annonces et qu’il retrouve par la suite une annonce qu’il a déjà scrapé la veille)

# %% [markdown]
# #### References & code:
# - https://medium.com/france-school-of-ai/web-scraping-avec-python-apprenez-%C3%A0-utiliser-beautifulsoup-proxies-et-un-faux-user-agent-d7bfb66b6556
# - https://towardsdatascience.com/looking-for-a-house-build-a-web-scraper-to-help-you-5ab25badc83e
# - https://medium.com/@ben.sturm/scraping-house-listing-data-using-selenium-and-beautiful-soup-1cbb94ba9492
